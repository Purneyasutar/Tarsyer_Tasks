# %%
pip install --user mediapipe opencv-python
# Out:
# Collecting mediapipe
#   Obtaining dependency information for mediapipe from https://files.pythonhosted.org/packages/ed/b1/978712efb3c370eca2d4224d1cac4582561f594eb759ba1ed4a082e9a704/mediapipe-0.10.8-cp311-cp311-win_amd64.whl.metadata
#   Using cached mediapipe-0.10.8-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: opencv-python in d:\softwares\ann\lib\site-packages (4.8.1.78)
# Collecting absl-py (from mediapipe)
#   Obtaining dependency information for absl-py from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Using cached absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: attrs>=19.1.0 in d:\softwares\ann\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in d:\softwares\ann\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in d:\softwares\ann\lib\site-packages (from mediapipe) (3.7.2)
# Requirement already satisfied: numpy in d:\softwares\ann\lib\site-packages (from mediapipe) (1.24.3)
# Collecting opencv-contrib-python (from mediapipe)
#   Obtaining dependency information for opencv-contrib-python from https://files.pythonhosted.org/packages/81/3c/bbb3ceee9fbefc505f98c24dafda68c7b3c4f83b6951c0712b4623fe4cce/opencv_contrib_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_contrib_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: protobuf<4,>=3.11 in d:\softwares\ann\lib\site-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Using cached sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
# Requirement already satisfied: CFFI>=1.0 in d:\softwares\ann\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\softwares\ann\lib\site-packages (from matplotlib->mediapipe) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\softwares\ann\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\softwares\ann\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\softwares\ann\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\softwares\ann\lib\site-packages (from matplotlib->mediapipe) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\softwares\ann\lib\site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\softwares\ann\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\softwares\ann\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in d:\softwares\ann\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in d:\softwares\ann\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Using cached mediapipe-0.10.8-cp311-cp311-win_amd64.whl (50.5 MB)
# Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Using cached opencv_contrib_python-4.8.1.78-cp37-abi3-win_amd64.whl (44.8 MB)
# Installing collected packages: opencv-contrib-python, absl-py, sounddevice, mediapipe
# Successfully installed absl-py-2.0.0 mediapipe-0.10.8 opencv-contrib-python-4.8.1.78 sounddevice-0.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp

def detect_fingers_landmarks(landmarks):
    finger_tips = [4, 8, 12, 16, 20]  
    finger_letters = ['T', 'I', 'M', 'R', 'B']

    for tip, letter in zip(finger_tips, finger_letters):
        if tip == 4:  
            if landmarks[tip].x < landmarks[tip + 1].x:
                x, y = int(landmarks[tip].x * width), int(landmarks[tip].y * height)
                cv2.putText(frame, letter, (x - 10, y + 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        elif landmarks[tip].y < landmarks[tip - 1].y:
            x, y = int(landmarks[tip].x * width), int(landmarks[tip].y * height)
            cv2.putText(frame, letter, (x - 10, y + 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)


mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

cap = cv2.VideoCapture(0)  
width, height = int(cap.get(3)), int(cap.get(4))
out = cv2.VideoWriter('C:/Users/kaush/Downloads/output_video.mp4', cv2.VideoWriter_fourcc(*'XVID'), 20.0, (width, height))

while cap.isOpened():
    # Read a frame from the camera
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    results = hands.process(rgb_frame)

    if results.multi_hand_landmarks:
        for landmarks in results.multi_hand_landmarks:

            mp_drawing = mp.solutions.drawing_utils
            mp_drawing.draw_landmarks(frame, landmarks, mp_hands.HAND_CONNECTIONS)

            detect_fingers_landmarks(landmarks.landmark)

    out.write(frame)

    cv2.imshow('Hand Tracking', frame)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break


cap.release()
out.release()
cv2.destroyAllWindows()
